# %% [markdown]
# <a href="https://colab.research.google.com/github/kunalgaurav18/CE888/blob/main/Lab_4/my_recommender.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
jester = pd.read_csv('https://raw.githubusercontent.com/albanda/CE888/master/lab4-recommender/jester-data-1.csv', header=None)
jester.head()
# Out:
#    0      1      2      3      4    ...    96     97     98     99     100
# 0   74  -7.82   8.79  -9.66  -8.16  ...  99.00  -5.63  99.00  99.00  99.00
# 1  100   4.08  -0.29   6.36   4.37  ...  -2.14   3.06   0.34  -4.32   1.07
# 2   49  99.00  99.00  99.00  99.00  ...  99.00  99.00  99.00  99.00  99.00
# 3   48  99.00   8.35  99.00  99.00  ...  99.00  99.00  99.00  99.00  99.00
# 4   91   8.50   4.61  -4.17  -5.39  ...   1.55   3.11   6.55   1.80   1.60
#
# [5 rows x 101 columns]

# %%
jester.describe().transpose()
# Out:
#        count       mean        std    min     25%    50%    75%    max
# 0    24983.0  72.467478  21.859600  36.00  53.000  72.00  100.0  100.0
# 1    24983.0  34.401435  46.707059  -9.95  -0.150   5.05   99.0   99.0
# 2    24983.0  27.094089  44.228006  -9.95  -2.180   3.69   99.0   99.0
# 3    24983.0  33.263717  46.747535  -9.95  -1.145   4.66   99.0   99.0
# 4    24983.0  36.244936  48.812967  -9.95  -3.350   3.45   99.0   99.0
# ..       ...        ...        ...    ...     ...    ...    ...    ...
# 96   24983.0  58.541104  48.130562  -9.95   3.300  99.00   99.0   99.0
# 97   24983.0  58.017246  48.164681  -9.95   3.590  99.00   99.0   99.0
# 98   24983.0  57.061650  48.717455  -9.95   2.670  99.00   99.0   99.0
# 99   24983.0  55.753357  49.237139  -9.95   1.335  99.00   99.0   99.0
# 100  24983.0  60.138090  47.913531  -9.95   3.930  99.00   99.0   99.0
#
# [101 rows x 8 columns]

# %%
jester_nan = jester.replace(99, np.nan)

# %%
jester_nan.isna().sum()
# Out:
# 0         81
# 1       8531
# 2       6799
# 3       8341
# 4       9375
#        ...
# 96     14613
# 97     14463
# 98     14317
# 99     14073
# 100    15040
# Length: 101, dtype: int64

# %%
len(jester[0].unique())
# Out:
# 65

# %%
jester_nan.drop(columns=0, axis=1, inplace=True)

# %%
jester_nan.head()
# Out:
#     1     2     3     4     5     6    ...   95    96    97    98    99    100
# 0 -7.82  8.79 -9.66 -8.16 -7.52 -8.50  ...   NaN   NaN -5.63   NaN   NaN   NaN
# 1  4.08 -0.29  6.36  4.37 -2.38 -9.66  ... -0.19 -2.14  3.06  0.34 -4.32  1.07
# 2   NaN   NaN   NaN   NaN  9.03  9.27  ...   NaN   NaN   NaN   NaN   NaN   NaN
# 3   NaN  8.35   NaN   NaN  1.80  8.16  ...   NaN   NaN   NaN   NaN   NaN   NaN
# 4  8.50  4.61 -4.17 -5.39  1.36  1.60  ...  5.73  1.55  3.11  6.55  1.80  1.60
#
# [5 rows x 100 columns]

# %%
jester_nan.mean().sort_values(ascending=True)
# Out:
# 58   -3.833880
# 16   -3.104818
# 44   -2.111891
# 57   -1.990664
# 13   -1.762882
#         ...
# 32    3.155988
# 27    3.189821
# 36    3.312500
# 89    3.574720
# 50    3.665085
# Length: 100, dtype: float64

# %%
arr = jester_nan.values

# %%
np.where(arr!= 99)
# Out:
# (array([    0,     0,     0, ..., 24982, 24982, 24982]),
#  array([ 0,  1,  2, ..., 97, 98, 99]))

# %%
def helper_function(orig, percentage=0.1):
  """
  Replaces 'percentage'% of the original values in 'orig' with 99's
  :param orig: original data array
  :param percentage: percentage of values to replace (0<percentage<1)
  """
  new_data = orig.copy()
  rated = np.where(~np.isnan(orig))
  n_rated = len(rated[0])
  idx = np.random.choice(n_rated, size=int(percentage*n_rated), replace=False)
  new_data[rated[0][idx], rated[1][idx]] = 99
  return new_data, (rated[0][idx], rated[1][idx])

# %%
new_arr, idx = helper_function(arr)

# %%
arr[idx[0][0], idx[1][0]]
# Out:
# 8.25

# %%
new_arr[idx[0][0], idx[1][0]]
# Out:
# 99.0

# %%
jester.groupby(0).count()
# Out:
#       1     2     3     4     5     6    ...   95    96    97    98    99    100
# 0                                        ...
# 36    482   482   482   482   482   482  ...   482   482   482   482   482   482
# 37    409   409   409   409   409   409  ...   409   409   409   409   409   409
# 38    413   413   413   413   413   413  ...   413   413   413   413   413   413
# 39    391   391   391   391   391   391  ...   391   391   391   391   391   391
# 40    407   407   407   407   407   407  ...   407   407   407   407   407   407
# ..    ...   ...   ...   ...   ...   ...  ...   ...   ...   ...   ...   ...   ...
# 96     68    68    68    68    68    68  ...    68    68    68    68    68    68
# 97     60    60    60    60    60    60  ...    60    60    60    60    60    60
# 98     71    71    71    71    71    71  ...    71    71    71    71    71    71
# 99     81    81    81    81    81    81  ...    81    81    81    81    81    81
# 100  7200  7200  7200  7200  7200  7200  ...  7200  7200  7200  7200  7200  7200
#
# [65 rows x 100 columns]

# %%
users = jester[0].unique()
users
# Out:
# array([ 74, 100,  49,  48,  91,  47,  72,  36,  51,  53,  55,  50,  67,
#         60,  54,  46,  38,  41,  73,  92,  89,  71,  40,  45,  62,  63,
#         61,  65,  68,  69,  37,  56,  66,  64,  82,  57,  75,  88,  86,
#         43,  83,  93,  94,  44,  59,  39,  58,  70,  78,  97,  90,  84,
#         98,  96,  52,  80,  42,  81,  76,  79,  85,  77,  95,  87,  99])

# %%
def predict_rating(user_id, item_id):
    """ Predict a rating given a user_id and an item_id.
    """
    user_preference = latent_user_preferences[user_id]
    item_preference = latent_item_features[item_id]
    return user_preference.dot(item_preference)


def train(user_id, item_id, rating, alpha=0.0001):
    #print(item_id)
    predicted_rating = predict_rating(user_id, item_id)
    err =  predicted_rating - rating
    #print(err)
    user_pref_values = latent_user_preferences[user_id]
    latent_user_preferences[user_id] -= alpha * err * latent_item_features[item_id]
    latent_item_features[item_id] -= alpha * err * user_pref_values
    return err
    

def sgd(iterations):
    """ Iterate over all users and all items and train for 
        a certain number of iterations
    """
    mse_history = []
    for iteration in range(iterations):
        error = []
        for user_id in range(latent_user_preferences.shape[0]):
            for item_id in range(latent_item_features.shape[0]):
                rating = user_ratings[user_id, item_id]
                if not np.isnan(rating):
                    err = train(user_id, item_id, rating)
                    error.append(err)
        mse = (np.array(error) ** 2).mean()   
        if (iteration % 5) == 0:
            print('Iteration %d/%d:\tMSE=%.6f' % (iteration, iterations, mse))
            mse_history.append(mse)
    return mse_history

# %%
n_latent_factors = 4

user_ratings = jester_nan.values
# Initialise as random values
latent_user_preferences = np.random.random((user_ratings.shape[0], n_latent_factors))
latent_item_features = np.random.random((user_ratings.shape[1], n_latent_factors))

# %% [markdown]
# # MSE of validation set

# %%
err  =[]
for u, i in zip(*idx):
  err.append(predict_rating(u,i) - user_ratings[u,i])
print('MSE of validation set: ', (np.array(err)**2).mean())
# Out:
# MSE of validation set:  15.681413447844411

# %% [markdown]
# # Prediction of test set

# %%
test_idx = np.where(np.isnan(user_ratings))
for u, i in zip(*test_idx):
  print('Prediction for {} user_id for item_id {} is {}'.format(u, i, predict_rating(u,i)))
# Out:
# Streaming output truncated to the last 5000 lines.
# Prediction for 24812 user_id for item_id 92 is -4.178679301102675
# Prediction for 24812 user_id for item_id 93 is -4.3385724117413655
# Prediction for 24812 user_id for item_id 94 is -4.446258034115898
# Prediction for 24812 user_id for item_id 95 is -4.379870365387201
# Prediction for 24813 user_id for item_id 70 is 0.42984049753408643
# Prediction for 24813 user_id for item_id 71 is 2.8909743653822964
# Prediction for 24813 user_id for item_id 72 is 1.5899737004546304
# Prediction for 24813 user_id for item_id 73 is -0.17084826408657883
# Prediction for 24813 user_id for item_id 74 is 0.5613531853518502
# Prediction for 24813 user_id for item_id 75 is 2.6324032401387765
# Prediction for 24813 user_id for item_id 76 is 1.3894643446655823
# Prediction for 24813 user_id for item_id 77 is 2.102113921447982
# Prediction for 24813 user_id for item_id 78 is 1.0330908555010732
# Prediction for 24813 user_id for item_id 79 is 1.7903137372278344
# Prediction for 24813 user_id for item_id 80 is 2.223131444263739
# Prediction for 24813 user_id for item_id 81 is 1.6591239527104165
# Prediction for 24813 user_id for item_id 83 is 1.5557135295010698
# Prediction for 24813 user_id for item_id 85 is 1.1542487236419865
# Prediction for 24813 user_id for item_id 86 is 2.2632466421029838
# Prediction for 24813 user_id for item_id 87 is 2.491598250145791
# Prediction for 24813 user_id for item_id 88 is 3.4303182173962448
# Prediction for 24813 user_id for item_id 89 is 1.5086950259086784
# Prediction for 24813 user_id for item_id 90 is 2.411136290275137
# Prediction for 24813 user_id for item_id 91 is 1.930800405590917
# Prediction for 24813 user_id for item_id 92 is 2.7873488101983015
# Prediction for 24813 user_id for item_id 93 is 1.8499107953837142
# Prediction for 24813 user_id for item_id 95 is 2.155758145634678
# Prediction for 24813 user_id for item_id 96 is 2.1999543398900543
# Prediction for 24813 user_id for item_id 97 is 1.5116648005143138
# Prediction for 24813 user_id for item_id 98 is 1.0349831494291464
# Prediction for 24813 user_id for item_id 99 is 1.8015503425943102
# Prediction for 24814 user_id for item_id 0 is 6.579381248131256
# Prediction for 24814 user_id for item_id 1 is 5.47612878494503
# Prediction for 24814 user_id for item_id 2 is 6.475951661030001
# Prediction for 24814 user_id for item_id 3 is 5.982160968010046
# Prediction for 24814 user_id for item_id 5 is 6.541549956482742
# Prediction for 24814 user_id for item_id 8 is 8.548681523623902
# Prediction for 24814 user_id for item_id 9 is 7.278468858142482
# Prediction for 24814 user_id for item_id 10 is 6.055969416247417
# Prediction for 24814 user_id for item_id 11 is 6.386357963667736
# Prediction for 24814 user_id for item_id 13 is 5.858616112745373
# Prediction for 24814 user_id for item_id 21 is 6.981019570137997
# Prediction for 24814 user_id for item_id 22 is 7.700956715262642
# Prediction for 24814 user_id for item_id 23 is 7.220774268444434
# Prediction for 24814 user_id for item_id 24 is 6.2000969341663295
# Prediction for 24814 user_id for item_id 25 is 5.663899178585067
# Prediction for 24814 user_id for item_id 28 is 4.233327560673704
# Prediction for 24814 user_id for item_id 29 is 7.5290085371050335
# Prediction for 24814 user_id for item_id 32 is 6.5728866984321925
# Prediction for 24814 user_id for item_id 36 is 6.902580899842466
# Prediction for 24814 user_id for item_id 37 is 7.652023420119044
# Prediction for 24814 user_id for item_id 38 is 5.671351650614546
# Prediction for 24814 user_id for item_id 40 is 7.077869624329522
# Prediction for 24814 user_id for item_id 42 is 7.584300422324484
# Prediction for 24814 user_id for item_id 43 is 6.716881844606952
# Prediction for 24814 user_id for item_id 44 is 6.92957735640257
# Prediction for 24814 user_id for item_id 50 is 5.472318883733747
# Prediction for 24814 user_id for item_id 51 is 5.675632366641871
# Prediction for 24814 user_id for item_id 53 is 5.933355515292281
# Prediction for 24814 user_id for item_id 54 is 7.98130595403618
# Prediction for 24814 user_id for item_id 56 is 7.307261566980395
# Prediction for 24814 user_id for item_id 57 is 5.258733768189475
# Prediction for 24814 user_id for item_id 58 is 7.538632015238137
# Prediction for 24814 user_id for item_id 59 is 7.67980661448371
# Prediction for 24814 user_id for item_id 62 is 7.69170666656995
# Prediction for 24814 user_id for item_id 63 is 7.250015884209534
# Prediction for 24814 user_id for item_id 66 is 7.813692115388061
# Prediction for 24814 user_id for item_id 71 is 4.811293906107115
# Prediction for 24814 user_id for item_id 72 is 4.662706836276075
# Prediction for 24814 user_id for item_id 73 is 5.0826241834512995
# Prediction for 24814 user_id for item_id 74 is 4.430062196403552
# Prediction for 24814 user_id for item_id 75 is 4.7593842772207555
# Prediction for 24814 user_id for item_id 76 is 5.0358714522957015
# Prediction for 24814 user_id for item_id 77 is 5.187108055152713
# Prediction for 24814 user_id for item_id 78 is 4.810268465559711
# Prediction for 24814 user_id for item_id 79 is 4.431363486655258
# Prediction for 24814 user_id for item_id 80 is 4.884435241891357
# Prediction for 24814 user_id for item_id 81 is 6.364798009999005
# Prediction for 24814 user_id for item_id 82 is 4.329704325000144
# Prediction for 24814 user_id for item_id 83 is 6.199649513965233
# Prediction for 24814 user_id for item_id 84 is 5.035872299630852
# Prediction for 24814 user_id for item_id 85 is 6.866789210394829
# Prediction for 24814 user_id for item_id 87 is 6.113469623549228
# Prediction for 24814 user_id for item_id 88 is 5.152964410590521
# Prediction for 24814 user_id for item_id 89 is 6.481634289172154
# Prediction for 24814 user_id for item_id 90 is 6.139276692024902
# Prediction for 24814 user_id for item_id 91 is 5.980540549335927
# Prediction for 24814 user_id for item_id 92 is 5.612824588498418
# Prediction for 24814 user_id for item_id 93 is 7.397925562437823
# Prediction for 24814 user_id for item_id 95 is 6.561363103656096
# Prediction for 24814 user_id for item_id 96 is 6.200813216099362
# Prediction for 24814 user_id for item_id 97 is 3.8200155495354786
# Prediction for 24814 user_id for item_id 98 is 6.042945592452588
# Prediction for 24814 user_id for item_id 99 is 4.489364749542574
# Prediction for 24815 user_id for item_id 70 is 1.2488365771527554
# Prediction for 24815 user_id for item_id 71 is 1.9133762572392539
# Prediction for 24815 user_id for item_id 72 is 0.8802747859739978
# Prediction for 24815 user_id for item_id 73 is 0.7953316130845354
# Prediction for 24815 user_id for item_id 74 is 0.6733631739297993
# Prediction for 24815 user_id for item_id 75 is 1.8289750250018562
# Prediction for 24815 user_id for item_id 76 is 1.0723378761683753
# Prediction for 24815 user_id for item_id 77 is 1.4064276847405073
# Prediction for 24815 user_id for item_id 78 is 0.7692464650410733
# Prediction for 24815 user_id for item_id 79 is 0.8649126149542269
# Prediction for 24815 user_id for item_id 80 is 1.7094104079190977
# Prediction for 24815 user_id for item_id 81 is 2.104723235574034
# Prediction for 24815 user_id for item_id 82 is 1.3584866685149173
# Prediction for 24815 user_id for item_id 83 is 1.968767409628128
# Prediction for 24815 user_id for item_id 84 is 1.2297252512401677
# Prediction for 24815 user_id for item_id 85 is 2.5077451527679564
# Prediction for 24815 user_id for item_id 87 is 2.591199156134593
# Prediction for 24815 user_id for item_id 88 is 2.5757858844365904
# Prediction for 24815 user_id for item_id 89 is 2.067422649892367
# Prediction for 24815 user_id for item_id 90 is 2.5834863098488254
# Prediction for 24815 user_id for item_id 91 is 2.1203507810845683
# Prediction for 24815 user_id for item_id 92 is 2.4212316033188426
# Prediction for 24815 user_id for item_id 93 is 2.9755121066294636
# Prediction for 24815 user_id for item_id 94 is 2.488664808900059
# Prediction for 24815 user_id for item_id 95 is 2.631757744992272
# Prediction for 24815 user_id for item_id 97 is 0.9094610870090987
# Prediction for 24815 user_id for item_id 98 is 1.8044533676547048
# Prediction for 24815 user_id for item_id 99 is 1.2569296617018664
# Prediction for 24816 user_id for item_id 0 is -0.29294568099395507
# Prediction for 24816 user_id for item_id 1 is 0.4912442340187167
# Prediction for 24816 user_id for item_id 2 is 0.19770135077265272
# Prediction for 24816 user_id for item_id 3 is 0.28668168019993134
# Prediction for 24816 user_id for item_id 8 is -1.5029932933980648
# Prediction for 24816 user_id for item_id 9 is -0.6219687265819659
# Prediction for 24816 user_id for item_id 11 is 1.3857744718444318
# Prediction for 24816 user_id for item_id 21 is 0.36050252470332034
# Prediction for 24816 user_id for item_id 22 is -0.6706402374090419
# Prediction for 24816 user_id for item_id 23 is -1.340116328506392
# Prediction for 24816 user_id for item_id 24 is 0.7766025480487663
# Prediction for 24816 user_id for item_id 29 is 0.08770437140659096
# Prediction for 24816 user_id for item_id 32 is -0.27000771046978905
# Prediction for 24816 user_id for item_id 33 is 1.3167404831926974
# Prediction for 24816 user_id for item_id 36 is -1.5322576399351409
# Prediction for 24816 user_id for item_id 37 is -0.31341567739639564
# Prediction for 24816 user_id for item_id 40 is -0.09118331311867783
# Prediction for 24816 user_id for item_id 42 is -0.9632777276037283
# Prediction for 24816 user_id for item_id 43 is -2.403588310884584
# Prediction for 24816 user_id for item_id 44 is 0.5117858277610378
# Prediction for 24816 user_id for item_id 45 is 0.862905177687189
# Prediction for 24816 user_id for item_id 46 is 0.7349071710252852
# Prediction for 24816 user_id for item_id 50 is 1.4282088900412018
# Prediction for 24816 user_id for item_id 54 is -0.9723308108719179
# Prediction for 24816 user_id for item_id 57 is -1.9734583624690207
# Prediction for 24816 user_id for item_id 58 is -0.40992783087240947
# Prediction for 24816 user_id for item_id 59 is -1.7915330689067857
# Prediction for 24816 user_id for item_id 62 is -0.360376232892232
# Prediction for 24816 user_id for item_id 63 is -1.0054067436103162
# Prediction for 24816 user_id for item_id 66 is -1.2650781512953162
# Prediction for 24816 user_id for item_id 69 is 0.5389960918413909
# Prediction for 24816 user_id for item_id 70 is 0.4342888060596746
# Prediction for 24816 user_id for item_id 71 is 2.5725949819648526
# Prediction for 24816 user_id for item_id 72 is 2.7407618952787853
# Prediction for 24816 user_id for item_id 73 is 0.5930594079123909
# Prediction for 24816 user_id for item_id 74 is 1.5436804580832841
# Prediction for 24816 user_id for item_id 75 is 2.2633890034385757
# Prediction for 24816 user_id for item_id 76 is 2.0770089350616026
# Prediction for 24816 user_id for item_id 77 is 2.5509524440817115
# Prediction for 24816 user_id for item_id 78 is 2.1949182204908255
# Prediction for 24816 user_id for item_id 79 is 3.041011520798359
# Prediction for 24816 user_id for item_id 80 is 2.183695230577372
# Prediction for 24816 user_id for item_id 81 is 0.9468709850298324
# Prediction for 24816 user_id for item_id 82 is 2.7603967769104525
# Prediction for 24816 user_id for item_id 83 is 1.0320679943593312
# Prediction for 24816 user_id for item_id 84 is 2.2277373632339117
# Prediction for 24816 user_id for item_id 85 is -0.5080852914328651
# Prediction for 24816 user_id for item_id 86 is 1.6189384899966228
# Prediction for 24816 user_id for item_id 87 is 1.021366293594223
# Prediction for 24816 user_id for item_id 88 is 1.939249494934403
# Prediction for 24816 user_id for item_id 89 is 0.8393081225213875
# Prediction for 24816 user_id for item_id 90 is 0.8962582850823417
# Prediction for 24816 user_id for item_id 91 is 1.135522189272576
# Prediction for 24816 user_id for item_id 92 is 1.613024839875585
# Prediction for 24816 user_id for item_id 93 is -0.24306611264460443
# Prediction for 24816 user_id for item_id 94 is 0.2538147400506472
# Prediction for 24816 user_id for item_id 95 is 0.6150757486265443
# Prediction for 24816 user_id for item_id 97 is 2.465412303768546
# Prediction for 24816 user_id for item_id 99 is 2.5632706829973286
# Prediction for 24817 user_id for item_id 0 is 4.040319796036099
# Prediction for 24817 user_id for item_id 2 is 4.1976966205833826
# Prediction for 24817 user_id for item_id 3 is 2.5527115284420554
# Prediction for 24817 user_id for item_id 8 is 1.9232576293243648
# Prediction for 24817 user_id for item_id 23 is 0.7403558776513198
# Prediction for 24817 user_id for item_id 36 is 1.2331531753034561
# Prediction for 24817 user_id for item_id 43 is -0.8580347277461464
# Prediction for 24817 user_id for item_id 56 is -0.5177934484421596
# Prediction for 24817 user_id for item_id 57 is -2.6014067927903373
# Prediction for 24817 user_id for item_id 70 is 1.0341532834862794
# Prediction for 24817 user_id for item_id 71 is 6.5269510751179185
# Prediction for 24817 user_id for item_id 73 is 0.7266807694760712
# Prediction for 24817 user_id for item_id 74 is 2.1018735880931776
# Prediction for 24817 user_id for item_id 75 is 5.575386315866397
# Prediction for 24817 user_id for item_id 76 is 3.162426699694644
# Prediction for 24817 user_id for item_id 77 is 4.820760854100186
# Prediction for 24817 user_id for item_id 78 is 3.152567751251399
# Prediction for 24817 user_id for item_id 79 is 5.3322072831000815
# Prediction for 24817 user_id for item_id 80 is 5.814453036160123
# Prediction for 24817 user_id for item_id 81 is 3.0229880788926424
# Prediction for 24817 user_id for item_id 82 is 6.006529154567567
# Prediction for 24817 user_id for item_id 84 is 4.751704969944315
# Prediction for 24817 user_id for item_id 85 is 0.9284078919966176
# Prediction for 24817 user_id for item_id 86 is 4.677627398705983
# Prediction for 24817 user_id for item_id 87 is 4.336718959926725
# Prediction for 24817 user_id for item_id 88 is 6.154599034200382
# Prediction for 24817 user_id for item_id 89 is 2.637655674168063
# Prediction for 24817 user_id for item_id 90 is 3.9820354283977073
# Prediction for 24817 user_id for item_id 91 is 3.568214225523508
# Prediction for 24817 user_id for item_id 92 is 5.297967504010045
# Prediction for 24817 user_id for item_id 93 is 2.085181182410509
# Prediction for 24817 user_id for item_id 94 is 2.6694690831615344
# Prediction for 24817 user_id for item_id 95 is 3.408479401306071
# Prediction for 24817 user_id for item_id 96 is 3.5451114705432785
# Prediction for 24817 user_id for item_id 97 is 5.484332855579136
# Prediction for 24817 user_id for item_id 98 is 2.0088328371528092
# Prediction for 24817 user_id for item_id 99 is 6.394110039214471
# Prediction for 24818 user_id for item_id 0 is 5.831422401704872
# Prediction for 24818 user_id for item_id 1 is 4.764002561775873
# Prediction for 24818 user_id for item_id 2 is 5.897447337450601
# Prediction for 24818 user_id for item_id 3 is 5.461298674595514
# Prediction for 24818 user_id for item_id 5 is 6.742704623433267
# Prediction for 24818 user_id for item_id 8 is 7.192599634912086
# Prediction for 24818 user_id for item_id 9 is 6.331883071609787
# Prediction for 24818 user_id for item_id 10 is 6.084112772877167
# Prediction for 24818 user_id for item_id 11 is 6.335959278355265
# Prediction for 24818 user_id for item_id 13 is 5.880750511628378
# Prediction for 24818 user_id for item_id 21 is 6.256673201570911
# Prediction for 24818 user_id for item_id 22 is 6.7513665081108805
# Prediction for 24818 user_id for item_id 23 is 5.947647976029284
# Prediction for 24818 user_id for item_id 24 is 5.7626897349963135
# Prediction for 24818 user_id for item_id 25 is 5.58590034619946
# Prediction for 24818 user_id for item_id 28 is 4.215009726631097
# Prediction for 24818 user_id for item_id 29 is 7.073514153144497
# Prediction for 24818 user_id for item_id 30 is 5.23370560486245
# Prediction for 24818 user_id for item_id 32 is 5.731778709662644
# Prediction for 24818 user_id for item_id 36 is 5.422635542743641
# Prediction for 24818 user_id for item_id 37 is 6.833807790300665
# Prediction for 24818 user_id for item_id 38 is 5.863491688215589
# Prediction for 24818 user_id for item_id 40 is 6.194194604088936
# Prediction for 24818 user_id for item_id 43 is 4.869600074123887
# Prediction for 24818 user_id for item_id 44 is 6.552292372757423
# Prediction for 24818 user_id for item_id 45 is 5.539340690373927
# Prediction for 24818 user_id for item_id 50 is 5.371495781022954
# Prediction for 24818 user_id for item_id 51 is 5.680151055658246
# Prediction for 24818 user_id for item_id 54 is 6.870099253918602
# Prediction for 24818 user_id for item_id 56 is 5.59558330782805
# Prediction for 24818 user_id for item_id 58 is 6.770673482852361
# Prediction for 24818 user_id for item_id 59 is 6.139442807358266
# Prediction for 24818 user_id for item_id 62 is 7.030814241202441
# Prediction for 24818 user_id for item_id 63 is 6.113665711314271
# Prediction for 24818 user_id for item_id 66 is 6.613426580461928
# Prediction for 24818 user_id for item_id 70 is 5.389647159503382
# Prediction for 24818 user_id for item_id 71 is 6.051907779394227
# Prediction for 24818 user_id for item_id 72 is 6.142730497843602
# Prediction for 24818 user_id for item_id 73 is 5.27855499901761
# Prediction for 24818 user_id for item_id 74 is 5.266145482826059
# Prediction for 24818 user_id for item_id 75 is 5.948604030821435
# Prediction for 24818 user_id for item_id 76 is 6.325259662292167
# Prediction for 24818 user_id for item_id 77 is 6.629319584672182
# Prediction for 24818 user_id for item_id 78 is 6.040272056020173
# Prediction for 24818 user_id for item_id 79 is 5.9618234574227165
# Prediction for 24818 user_id for item_id 80 is 5.74887743076865
# Prediction for 24818 user_id for item_id 82 is 5.650684780428251
# Prediction for 24818 user_id for item_id 83 is 6.75811648191062
# Prediction for 24818 user_id for item_id 84 is 5.976504478390985
# Prediction for 24818 user_id for item_id 85 is 6.692911588704996
# Prediction for 24818 user_id for item_id 86 is 6.015378800206264
# Prediction for 24818 user_id for item_id 87 is 6.6448708057575585
# Prediction for 24818 user_id for item_id 88 is 6.240533610613166
# Prediction for 24818 user_id for item_id 89 is 6.995393199288556
# Prediction for 24818 user_id for item_id 90 is 6.6507688808716035
# Prediction for 24818 user_id for item_id 91 is 6.611316461351514
# Prediction for 24818 user_id for item_id 92 is 6.436393602760335
# Prediction for 24818 user_id for item_id 93 is 7.367327276766878
# Prediction for 24818 user_id for item_id 94 is 6.515187501602711
# Prediction for 24818 user_id for item_id 95 is 6.922967190849976
# Prediction for 24818 user_id for item_id 97 is 4.703307221131996
# Prediction for 24818 user_id for item_id 98 is 6.322229805223154
# Prediction for 24818 user_id for item_id 99 is 5.282654983894284
# Prediction for 24821 user_id for item_id 0 is -2.4772079154670483
# Prediction for 24821 user_id for item_id 2 is -1.8636584963382627
# Prediction for 24821 user_id for item_id 3 is -3.0161103673600427
# Prediction for 24821 user_id for item_id 8 is -7.4101971797799715
# Prediction for 24821 user_id for item_id 23 is -7.415597378923937
# Prediction for 24821 user_id for item_id 29 is -3.387729037552645
# Prediction for 24821 user_id for item_id 32 is -4.2951726097197245
# Prediction for 24821 user_id for item_id 36 is -7.123953872744612
# Prediction for 24821 user_id for item_id 37 is -2.4820978314779647
# Prediction for 24821 user_id for item_id 40 is -3.210149843875424
# Prediction for 24821 user_id for item_id 42 is -6.104044773369941
# Prediction for 24821 user_id for item_id 43 is -9.890272853624094
# Prediction for 24821 user_id for item_id 54 is -4.758292739688969
# Prediction for 24821 user_id for item_id 56 is -9.700977458988138
# Prediction for 24821 user_id for item_id 57 is -9.72642220094284
# Prediction for 24821 user_id for item_id 58 is -4.457413094402003
# Prediction for 24821 user_id for item_id 59 is -7.408916542605623
# Prediction for 24821 user_id for item_id 63 is -5.7780026348166125
# Prediction for 24821 user_id for item_id 66 is -6.7463886856815245
# Prediction for 24821 user_id for item_id 69 is -1.09009486045412
# Prediction for 24821 user_id for item_id 70 is -2.3415454598924166
# Prediction for 24821 user_id for item_id 71 is 5.640558362562038
# Prediction for 24821 user_id for item_id 72 is 4.211541734410034
# Prediction for 24821 user_id for item_id 73 is -2.6565465149742233
# Prediction for 24821 user_id for item_id 74 is 0.5967822973518623
# Prediction for 24821 user_id for item_id 75 is 4.6034563383042855
# Prediction for 24821 user_id for item_id 76 is 2.177398191158907
# Prediction for 24821 user_id for item_id 77 is 4.068148065627953
# Prediction for 24821 user_id for item_id 78 is 2.2188257558625777
# Prediction for 24821 user_id for item_id 79 is 5.357482516996338
# Prediction for 24821 user_id for item_id 80 is 4.066302665772956
# Prediction for 24821 user_id for item_id 81 is -0.5839984778800343
# Prediction for 24821 user_id for item_id 82 is 5.658320968080731
# Prediction for 24821 user_id for item_id 83 is -0.4040323209278397
# Prediction for 24821 user_id for item_id 84 is 3.048636128947872
# Prediction for 24821 user_id for item_id 85 is -4.622871899851344
# Prediction for 24821 user_id for item_id 86 is 2.5162771093503786
# Prediction for 24821 user_id for item_id 87 is 0.9081859880815211
# Prediction for 24821 user_id for item_id 88 is 4.659708302287245
# Prediction for 24821 user_id for item_id 89 is -1.117357617374808
# Prediction for 24821 user_id for item_id 90 is 0.4856013742879267
# Prediction for 24821 user_id for item_id 91 is 0.4511929823154676
# Prediction for 24821 user_id for item_id 92 is 2.887597713315133
# Prediction for 24821 user_id for item_id 93 is -3.5506744121574974
# Prediction for 24821 user_id for item_id 94 is -1.8519190395233103
# Prediction for 24821 user_id for item_id 95 is -0.7336872575957257
# Prediction for 24821 user_id for item_id 96 is -0.32034742970087016
# Prediction for 24821 user_id for item_id 97 is 4.589190485797508
# Prediction for 24821 user_id for item_id 98 is -1.9214406405968831
# Prediction for 24821 user_id for item_id 99 is 4.814166100774232
# Prediction for 24822 user_id for item_id 0 is -3.006793725977701
# Prediction for 24822 user_id for item_id 1 is -2.123099332927121
# Prediction for 24822 user_id for item_id 2 is -3.1451785323749712
# Prediction for 24822 user_id for item_id 3 is -4.360610847836982
# Prediction for 24822 user_id for item_id 5 is -0.8480983795879443
# Prediction for 24822 user_id for item_id 8 is -6.3149725906424115
# Prediction for 24822 user_id for item_id 9 is -3.3808333530453365
# Prediction for 24822 user_id for item_id 10 is -0.6065199627650909
# Prediction for 24822 user_id for item_id 11 is -0.66634246844314
# Prediction for 24822 user_id for item_id 13 is -0.22363380711291558
# Prediction for 24822 user_id for item_id 21 is -2.595408760871977
# Prediction for 24822 user_id for item_id 23 is -6.479963356841428
# Prediction for 24822 user_id for item_id 24 is -2.204442248874432
# Prediction for 24822 user_id for item_id 29 is -4.338321848152305
# Prediction for 24822 user_id for item_id 32 is -4.941861937382383
# Prediction for 24822 user_id for item_id 36 is -6.046937886488624
# Prediction for 24822 user_id for item_id 39 is -1.7833860188295432
# Prediction for 24822 user_id for item_id 40 is -4.287886884632183
# Prediction for 24822 user_id for item_id 42 is -5.59565497819736
# Prediction for 24822 user_id for item_id 43 is -7.507619068959649
# Prediction for 24822 user_id for item_id 50 is -2.38826232903803
# Prediction for 24822 user_id for item_id 51 is -1.834067609018757
# Prediction for 24822 user_id for item_id 54 is -4.421812324769419
# Prediction for 24822 user_id for item_id 56 is -7.545585017075006
# Prediction for 24822 user_id for item_id 57 is -7.675141923102307
# Prediction for 24822 user_id for item_id 58 is -4.792749512976449
# Prediction for 24822 user_id for item_id 59 is -5.933536380817565
# Prediction for 24822 user_id for item_id 62 is -3.884761075668642
# Prediction for 24822 user_id for item_id 63 is -5.357137292040502
# Prediction for 24822 user_id for item_id 66 is -5.90905900206673
# Prediction for 24822 user_id for item_id 69 is -2.6132848553563655
# Prediction for 24822 user_id for item_id 70 is -3.0925767864030154
# Prediction for 24822 user_id for item_id 71 is 1.8224158286235521
# Prediction for 24822 user_id for item_id 72 is 0.37507530486074336
# Prediction for 24822 user_id for item_id 73 is -3.7412798128650016
# Prediction for 24822 user_id for item_id 75 is 1.3385346621479581
# Prediction for 24822 user_id for item_id 76 is -0.5869473559955308
# Prediction for 24822 user_id for item_id 77 is 0.5313741717426543
# Prediction for 24822 user_id for item_id 78 is -0.8291466041365724
# Prediction for 24822 user_id for item_id 79 is 0.9941830135013799
# Prediction for 24822 user_id for item_id 80 is 0.589526213109086
# Prediction for 24822 user_id for item_id 81 is -2.047393819884898
# Prediction for 24822 user_id for item_id 82 is 1.5929293825017938
# Prediction for 24822 user_id for item_id 83 is -2.0049009467135583
# Prediction for 24822 user_id for item_id 84 is -0.4145476566546938
# Prediction for 24822 user_id for item_id 85 is -4.065034840346197
# Prediction for 24822 user_id for item_id 86 is 0.05896291258373827
# Prediction for 24822 user_id for item_id 87 is -0.7223231410043993
# Prediction for 24822 user_id for item_id 88 is 1.8809800373807999
# Prediction for 24822 user_id for item_id 89 is -2.4001556642961126
# Prediction for 24822 user_id for item_id 90 is -0.9220411620683145
# Prediction for 24822 user_id for item_id 91 is -1.2710017536759732
# Prediction for 24822 user_id for item_id 92 is 0.4443561427509298
# Prediction for 24822 user_id for item_id 93 is -3.3788222600563627
# Prediction for 24822 user_id for item_id 94 is -2.4371845439408952
# Prediction for 24822 user_id for item_id 95 is -1.7706643367934443
# Prediction for 24822 user_id for item_id 96 is -1.4160494755947233
# Prediction for 24822 user_id for item_id 97 is 0.6322815142938264
# Prediction for 24822 user_id for item_id 98 is -2.8959410932746157
# Prediction for 24822 user_id for item_id 99 is 0.5352156718535015
# Prediction for 24823 user_id for item_id 57 is 1.4379828278742437
# Prediction for 24823 user_id for item_id 70 is 1.2333540139284545
# Prediction for 24823 user_id for item_id 71 is 1.1506620667738259
# Prediction for 24823 user_id for item_id 72 is 1.800115454209115
# Prediction for 24823 user_id for item_id 73 is 1.7620898192266048
# Prediction for 24823 user_id for item_id 74 is 1.6254081183839157
# Prediction for 24823 user_id for item_id 75 is 0.9917215307348469
# Prediction for 24823 user_id for item_id 76 is 1.4521797243946122
# Prediction for 24823 user_id for item_id 77 is 1.4629310981354273
# Prediction for 24823 user_id for item_id 78 is 1.7873591577930537
# Prediction for 24823 user_id for item_id 79 is 1.9159048911628993
# Prediction for 24823 user_id for item_id 80 is 1.478932323220826
# Prediction for 24823 user_id for item_id 81 is 1.0934883581144361
# Prediction for 24823 user_id for item_id 82 is 1.4751971302896372
# Prediction for 24823 user_id for item_id 83 is 1.1885115996432547
# Prediction for 24823 user_id for item_id 84 is 1.8873729452181143
# Prediction for 24823 user_id for item_id 85 is 0.5803128006554789
# Prediction for 24823 user_id for item_id 86 is 0.9723871005201693
# Prediction for 24823 user_id for item_id 87 is 0.6565557440377492
# Prediction for 24823 user_id for item_id 88 is 0.3764880776564192
# Prediction for 24823 user_id for item_id 89 is 1.1118181236052953
# Prediction for 24823 user_id for item_id 90 is 0.5888630669780847
# Prediction for 24823 user_id for item_id 91 is 0.9700351899180687
# Prediction for 24823 user_id for item_id 92 is 0.7423905013270562
# Prediction for 24823 user_id for item_id 93 is 0.4685529861442529
# Prediction for 24823 user_id for item_id 94 is 0.6880329203796018
# Prediction for 24823 user_id for item_id 95 is 0.666846576400099
# Prediction for 24823 user_id for item_id 97 is 1.9206892731914138
# Prediction for 24823 user_id for item_id 98 is 1.1893846597253823
# Prediction for 24823 user_id for item_id 99 is 2.111587409184692
# Prediction for 24825 user_id for item_id 0 is 1.3463849020000702
# Prediction for 24825 user_id for item_id 1 is 1.9478860588525018
# Prediction for 24825 user_id for item_id 2 is 0.957412386509181
# Prediction for 24825 user_id for item_id 3 is -1.2029895364637682
# Prediction for 24825 user_id for item_id 8 is -1.4540221037789303
# Prediction for 24825 user_id for item_id 23 is -2.72265120075454
# Prediction for 24825 user_id for item_id 36 is -2.098454363379759
# Prediction for 24825 user_id for item_id 42 is -1.4925596911998886
# Prediction for 24825 user_id for item_id 43 is -4.040001574249742
# Prediction for 24825 user_id for item_id 56 is -3.8073433674035373
# Prediction for 24825 user_id for item_id 57 is -5.739425920439737
# Prediction for 24825 user_id for item_id 59 is -1.352382966183307
# Prediction for 24825 user_id for item_id 70 is -0.9344966657099426
# Prediction for 24825 user_id for item_id 71 is 5.019788812724776
# Prediction for 24825 user_id for item_id 72 is 2.5519602587165258
# Prediction for 24825 user_id for item_id 74 is 0.11898725045932815
# Prediction for 24825 user_id for item_id 75 is 4.285975413240645
# Prediction for 24825 user_id for item_id 77 is 3.16286359913949
# Prediction for 24825 user_id for item_id 78 is 1.136519423874835
# Prediction for 24825 user_id for item_id 79 is 3.2752080276934312
# Prediction for 24825 user_id for item_id 80 is 3.711167138243619
# Prediction for 24825 user_id for item_id 81 is 1.1425833724062076
# Prediction for 24825 user_id for item_id 82 is 4.277774954907616
# Prediction for 24825 user_id for item_id 83 is 1.0785296962837578
# Prediction for 24825 user_id for item_id 85 is -0.7752902891998164
# Prediction for 24825 user_id for item_id 86 is 3.1466371075215713
# Prediction for 24825 user_id for item_id 87 is 2.8940879369671797
# Prediction for 24825 user_id for item_id 88 is 5.4124538213964914
# Prediction for 24825 user_id for item_id 89 is 0.7299561567221673
# Prediction for 24825 user_id for item_id 90 is 2.624111517895663
# Prediction for 24825 user_id for item_id 91 is 1.9030798041215533
# Prediction for 24825 user_id for item_id 92 is 3.9552805405809246
# Prediction for 24825 user_id for item_id 93 is 0.46373325446391844
# Prediction for 24825 user_id for item_id 94 is 0.9911167496125171
# Prediction for 24825 user_id for item_id 95 is 1.8442173753988094
# Prediction for 24825 user_id for item_id 96 is 2.0999110555407214
# Prediction for 24825 user_id for item_id 97 is 3.042479895479151
# Prediction for 24825 user_id for item_id 98 is -0.051903382400036085
# Prediction for 24825 user_id for item_id 99 is 3.5264528267230855
# Prediction for 24826 user_id for item_id 0 is 1.7979622376411257
# Prediction for 24826 user_id for item_id 1 is 0.8025903583261921
# Prediction for 24826 user_id for item_id 2 is 1.2107582009352893
# Prediction for 24826 user_id for item_id 3 is -1.024371884423193
# Prediction for 24826 user_id for item_id 5 is 4.800851483596788
# Prediction for 24826 user_id for item_id 8 is -0.37991439073179406
# Prediction for 24826 user_id for item_id 9 is 2.043802037887487
# Prediction for 24826 user_id for item_id 10 is 4.1629213975724975
# Prediction for 24826 user_id for item_id 11 is 4.172445794985707
# Prediction for 24826 user_id for item_id 13 is 3.979760918043051
# Prediction for 24826 user_id for item_id 21 is 1.9752817104735083
# Prediction for 24826 user_id for item_id 22 is 1.1959208969400443
# Prediction for 24826 user_id for item_id 23 is -2.1227359623671327
# Prediction for 24826 user_id for item_id 24 is 1.7489606596569602
# Prediction for 24826 user_id for item_id 25 is 3.5975141555020236
# Prediction for 24826 user_id for item_id 29 is 1.1616846731960195
# Prediction for 24826 user_id for item_id 32 is -1.160396107451554
# Prediction for 24826 user_id for item_id 33 is 3.2610775813968345
# Prediction for 24826 user_id for item_id 36 is -2.0942718198660004
# Prediction for 24826 user_id for item_id 38 is 3.7314971057288036
# Prediction for 24826 user_id for item_id 39 is 2.8443528440350385
# Prediction for 24826 user_id for item_id 40 is -0.03018507103607523
# Prediction for 24826 user_id for item_id 42 is -0.31494731531626474
# Prediction for 24826 user_id for item_id 43 is -4.001516881678381
# Prediction for 24826 user_id for item_id 44 is 3.125329673257444
# Prediction for 24826 user_id for item_id 46 is 4.960758006055778
# Prediction for 24826 user_id for item_id 50 is 0.571632611752221
# Prediction for 24826 user_id for item_id 51 is 1.6672518449760285
# Prediction for 24826 user_id for item_id 54 is 1.4722037087726778
# Prediction for 24826 user_id for item_id 57 is -5.56534810304208
# Prediction for 24826 user_id for item_id 58 is 0.4906674641468623
# Prediction for 24826 user_id for item_id 62 is 2.1119176270790794
# Prediction for 24826 user_id for item_id 63 is -0.6632450239353849
# Prediction for 24826 user_id for item_id 66 is -0.5962586525576955
# Prediction for 24826 user_id for item_id 69 is 2.853931371815787
# Prediction for 24826 user_id for item_id 71 is 7.281873271054768
# Prediction for 24826 user_id for item_id 72 is 5.426043503571651
# Prediction for 24826 user_id for item_id 73 is 0.095885227996127
# Prediction for 24826 user_id for item_id 74 is 2.536885364475182
# Prediction for 24826 user_id for item_id 75 is 6.8541340439968055
# Prediction for 24826 user_id for item_id 76 is 4.967467403758565
# Prediction for 24826 user_id for item_id 77 is 6.402630307877442
# Prediction for 24826 user_id for item_id 78 is 4.075579416198673
# Prediction for 24826 user_id for item_id 79 is 5.736338276035677
# Prediction for 24826 user_id for item_id 80 is 5.295827383513474
# Prediction for 24826 user_id for item_id 81 is 4.210821897162851
# Prediction for 24826 user_id for item_id 82 is 6.35360002714486
# Prediction for 24826 user_id for item_id 83 is 4.01252925205098
# Prediction for 24826 user_id for item_id 85 is 2.2860293878445863
# Prediction for 24826 user_id for item_id 86 is 5.5522546451734005
# Prediction for 24826 user_id for item_id 87 is 5.657647842593197
# Prediction for 24826 user_id for item_id 88 is 8.258917008182275
# Prediction for 24826 user_id for item_id 89 is 3.936493502601623
# Prediction for 24826 user_id for item_id 90 is 5.5334358584297965
# Prediction for 24826 user_id for item_id 91 is 4.819323863473393
# Prediction for 24826 user_id for item_id 92 is 6.5972410526424445
# Prediction for 24826 user_id for item_id 93 is 3.8078768390026037
# Prediction for 24826 user_id for item_id 94 is 3.6797116415315836
# Prediction for 24826 user_id for item_id 95 is 4.856047921413076
# Prediction for 24826 user_id for item_id 96 is 4.902549948236819
# Prediction for 24826 user_id for item_id 97 is 3.8228736118184856
# Prediction for 24826 user_id for item_id 98 is 2.5944271326108717
# Prediction for 24826 user_id for item_id 99 is 4.088630062960335
# Prediction for 24827 user_id for item_id 0 is 2.884300853076483
# Prediction for 24827 user_id for item_id 1 is 1.7929965728355293
# Prediction for 24827 user_id for item_id 2 is 2.4797843812488076
# Prediction for 24827 user_id for item_id 3 is 0.7272008567101036
# Prediction for 24827 user_id for item_id 8 is 1.6435221005339002
# Prediction for 24827 user_id for item_id 9 is 3.188988982866141
# Prediction for 24827 user_id for item_id 23 is 0.010925732112561702
# Prediction for 24827 user_id for item_id 29 is 2.829735108461966
# Prediction for 24827 user_id for item_id 32 is 0.6730108260029072
# Prediction for 24827 user_id for item_id 36 is -0.15884733155495756
# Prediction for 24827 user_id for item_id 42 is 1.5659099277459634
# Prediction for 24827 user_id for item_id 43 is -1.737325996452712
# Prediction for 24827 user_id for item_id 50 is 1.8808332040843094
# Prediction for 24827 user_id for item_id 54 is 2.918184628965344
# Prediction for 24827 user_id for item_id 56 is -1.0143201896371958
# Prediction for 24827 user_id for item_id 57 is -3.1393293814532695
# Prediction for 24827 user_id for item_id 63 is 1.1327037718841149
# Prediction for 24827 user_id for item_id 66 is 1.3335427459313651
# Prediction for 24827 user_id for item_id 69 is 3.982413416506765
# Prediction for 24827 user_id for item_id 71 is 7.211367270551287
# Prediction for 24827 user_id for item_id 72 is 5.928912671926716
# Prediction for 24827 user_id for item_id 73 is 1.6375441910200481
# Prediction for 24827 user_id for item_id 74 is 3.496580182501443
# Prediction for 24827 user_id for item_id 75 is 6.879157758965485
# Prediction for 24827 user_id for item_id 76 is 5.651875278595308
# Prediction for 24827 user_id for item_id 77 is 6.7904452681685585
# Prediction for 24827 user_id for item_id 78 is 4.894124515805496
# Prediction for 24827 user_id for item_id 79 is 6.09163850368226
# Prediction for 24827 user_id for item_id 80 is 5.612154982591531
# Prediction for 24827 user_id for item_id 81 is 5.176670563952623
# Prediction for 24827 user_id for item_id 83 is 4.986895507665594
# Prediction for 24827 user_id for item_id 84 is 4.881684877782433
# Prediction for 24827 user_id for item_id 85 is 3.6473196082306094
# Prediction for 24827 user_id for item_id 86 is 5.904256311418688
# Prediction for 24827 user_id for item_id 87 is 6.14776346676152
# Prediction for 24827 user_id for item_id 89 is 5.005261749518684
# Prediction for 24827 user_id for item_id 90 is 6.063333367458067
# Prediction for 24827 user_id for item_id 91 is 5.541473066988004
# Prediction for 24827 user_id for item_id 92 is 6.797304486504392
# Prediction for 24827 user_id for item_id 93 is 4.971906374922937
# Prediction for 24827 user_id for item_id 94 is 4.626844792289542
# Prediction for 24827 user_id for item_id 95 is 5.634943621207604
# Prediction for 24827 user_id for item_id 96 is 5.560240222011237
# Prediction for 24827 user_id for item_id 97 is 4.211650785267219
# Prediction for 24827 user_id for item_id 98 is 3.791915923188606
# Prediction for 24827 user_id for item_id 99 is 4.548767773791349
# Prediction for 24828 user_id for item_id 0 is 2.042948303991558
# Prediction for 24828 user_id for item_id 1 is -1.0212108416906411
# Prediction for 24828 user_id for item_id 2 is 1.0687091834603786
# Prediction for 24828 user_id for item_id 3 is 0.31190706976149435
# Prediction for 24828 user_id for item_id 5 is 1.6170461553499262
# Prediction for 24828 user_id for item_id 8 is 3.97270913704845
# Prediction for 24828 user_id for item_id 9 is 2.690765920473253
# Prediction for 24828 user_id for item_id 10 is 0.45262066376213184
# Prediction for 24828 user_id for item_id 11 is 0.12840559043762587
# Prediction for 24828 user_id for item_id 13 is -0.782908799223976
# Prediction for 24828 user_id for item_id 21 is 0.42858878091534014
# Prediction for 24828 user_id for item_id 22 is 2.9077484900532595
# Prediction for 24828 user_id for item_id 23 is 2.704179211451029
# Prediction for 24828 user_id for item_id 24 is -0.1697309588829067
# Prediction for 24828 user_id for item_id 25 is -0.9612466561680971
# Prediction for 24828 user_id for item_id 29 is 2.5025718674426773
# Prediction for 24828 user_id for item_id 32 is 1.020241048479904
# Prediction for 24828 user_id for item_id 36 is 2.2700698187994472
# Prediction for 24828 user_id for item_id 38 is -0.44935946238315644
# Prediction for 24828 user_id for item_id 39 is 0.46185187682769946
# Prediction for 24828 user_id for item_id 40 is 0.8198312473651473
# Prediction for 24828 user_id for item_id 44 is 1.5662524383060497
# Prediction for 24828 user_id for item_id 46 is 2.850035183841338
# Prediction for 24828 user_id for item_id 50 is -1.4335236538923406
# Prediction for 24828 user_id for item_id 51 is -1.0113328896999527
# Prediction for 24828 user_id for item_id 54 is 3.3844889398526914
# Prediction for 24828 user_id for item_id 57 is 2.025687707917227
# Prediction for 24828 user_id for item_id 58 is 2.6215935135795774
# Prediction for 24828 user_id for item_id 59 is 3.5037773223100004
# Prediction for 24828 user_id for item_id 63 is 2.5435497804791876
# Prediction for 24828 user_id for item_id 66 is 3.41244706448843
# Prediction for 24828 user_id for item_id 69 is 2.1673873705399513
# Prediction for 24828 user_id for item_id 70 is 2.889652493469514
# Prediction for 24828 user_id for item_id 71 is 1.4391712034745225
# Prediction for 24828 user_id for item_id 72 is 1.4518462236171565
# Prediction for 24828 user_id for item_id 73 is 1.9749237470326697
# Prediction for 24828 user_id for item_id 74 is 1.7776242296570797
# Prediction for 24828 user_id for item_id 75 is 2.0543456637967576
# Prediction for 24828 user_id for item_id 77 is 2.368081055899091
# Prediction for 24828 user_id for item_id 78 is 1.9179284294510557
# Prediction for 24828 user_id for item_id 79 is 0.6722257841410033
# Prediction for 24828 user_id for item_id 80 is 0.7538375378404479
# Prediction for 24828 user_id for item_id 81 is 3.8367020294960508
# Prediction for 24828 user_id for item_id 82 is 0.7353047637031268
# Prediction for 24828 user_id for item_id 83 is 3.520421898070603
# Prediction for 24828 user_id for item_id 84 is 0.8008624462365844
# Prediction for 24828 user_id for item_id 85 is 5.276500511676287
# Prediction for 24828 user_id for item_id 86 is 2.445805147343588
# Prediction for 24828 user_id for item_id 88 is 3.125927343122977
# Prediction for 24828 user_id for item_id 89 is 4.072679758019416
# Prediction for 24828 user_id for item_id 90 is 4.001071981908253
# Prediction for 24828 user_id for item_id 91 is 3.5282072829723354
# Prediction for 24828 user_id for item_id 92 is 2.9922804264882554
# Prediction for 24828 user_id for item_id 93 is 5.657445012472133
# Prediction for 24828 user_id for item_id 94 is 4.17767178514333
# Prediction for 24828 user_id for item_id 95 is 4.360963503504313
# Prediction for 24828 user_id for item_id 96 is 4.057501613006521
# Prediction for 24828 user_id for item_id 97 is -0.9278446380190228
# Prediction for 24828 user_id for item_id 98 is 3.4663279506121043
# Prediction for 24828 user_id for item_id 99 is -1.146614760682362
# Prediction for 24830 user_id for item_id 8 is 2.085227478202798
# Prediction for 24830 user_id for item_id 23 is -0.8798162059593054
# Prediction for 24830 user_id for item_id 36 is -0.46088093182965256
# Prediction for 24830 user_id for item_id 43 is 0.02455565171658934
# Prediction for 24830 user_id for item_id 56 is 0.4255817453811592
# Prediction for 24830 user_id for item_id 57 is -3.123341469862331
# Prediction for 24830 user_id for item_id 66 is 1.1210787301822263
# Prediction for 24830 user_id for item_id 70 is 0.03360299027241936
# Prediction for 24830 user_id for item_id 71 is 1.002978127167073
# Prediction for 24830 user_id for item_id 73 is -2.720265683602691
# Prediction for 24830 user_id for item_id 74 is -1.9435740388611469
# Prediction for 24830 user_id for item_id 75 is 1.7663516363496918
# Prediction for 24830 user_id for item_id 76 is 0.21340589122222892
# Prediction for 24830 user_id for item_id 78 is -1.8168773926772561
# Prediction for 24830 user_id for item_id 79 is -2.6755755172946674
# Prediction for 24830 user_id for item_id 80 is -1.063985070451178
# Prediction for 24830 user_id for item_id 81 is 2.3850812494801654
# Prediction for 24830 user_id for item_id 82 is -0.9926196044861757
# Prediction for 24830 user_id for item_id 83 is 1.7467773618691587
# Prediction for 24830 user_id for item_id 84 is -2.692602441734998
# Prediction for 24830 user_id for item_id 85 is 4.653867192030733
# Prediction for 24830 user_id for item_id 86 is 1.8823571004807236
# Prediction for 24830 user_id for item_id 87 is 4.118801593774906
# Prediction for 24830 user_id for item_id 88 is 5.07508776770691
# Prediction for 24830 user_id for item_id 89 is 2.4317609901491024
# Prediction for 24830 user_id for item_id 90 is 4.4966409421145475
# Prediction for 24830 user_id for item_id 91 is 2.6395969489122275
# Prediction for 24830 user_id for item_id 92 is 3.4590332482558708
# Prediction for 24830 user_id for item_id 93 is 5.919890852477479
# Prediction for 24830 user_id for item_id 94 is 3.834828431706061
# Prediction for 24830 user_id for item_id 95 is 4.424577621874483
# Prediction for 24830 user_id for item_id 96 is 4.353820555281887
# Prediction for 24830 user_id for item_id 97 is -4.438044445313846
# Prediction for 24830 user_id for item_id 98 is 1.2405821052187573
# Prediction for 24830 user_id for item_id 99 is -4.864627448691052
# Prediction for 24831 user_id for item_id 70 is -7.062805478172269
# Prediction for 24831 user_id for item_id 71 is -4.445521913261953
# Prediction for 24831 user_id for item_id 72 is -6.307195259479279
# Prediction for 24831 user_id for item_id 73 is -8.27764965099748
# Prediction for 24831 user_id for item_id 74 is -6.699448355803772
# Prediction for 24831 user_id for item_id 75 is -4.36423703275322
# Prediction for 24831 user_id for item_id 76 is -6.364732399425895
# Prediction for 24831 user_id for item_id 77 is -5.946574218418976
# Prediction for 24831 user_id for item_id 78 is -6.9281306642448355
# Prediction for 24831 user_id for item_id 79 is -6.065017088914375
# Prediction for 24831 user_id for item_id 80 is -5.609012458005032
# Prediction for 24831 user_id for item_id 81 is -7.114286811496673
# Prediction for 24831 user_id for item_id 82 is -4.858627968932777
# Prediction for 24831 user_id for item_id 83 is -7.1629439975999025
# Prediction for 24831 user_id for item_id 84 is -6.962235751206601
# Prediction for 24831 user_id for item_id 85 is -7.36465795611918
# Prediction for 24831 user_id for item_id 86 is -5.1697422688941685
# Prediction for 24831 user_id for item_id 87 is -5.501222169488134
# Prediction for 24831 user_id for item_id 89 is -7.393577372336844
# Prediction for 24831 user_id for item_id 90 is -5.493872330223919
# Prediction for 24831 user_id for item_id 91 is -6.280835920376845
# Prediction for 24831 user_id for item_id 92 is -4.818950221400016
# Prediction for 24831 user_id for item_id 93 is -7.184718287616571
# Prediction for 24831 user_id for item_id 94 is -6.501924347307954
# Prediction for 24831 user_id for item_id 95 is -6.292098923648422
# Prediction for 24831 user_id for item_id 96 is -5.758072108103306
# Prediction for 24831 user_id for item_id 97 is -5.710922669513497
# Prediction for 24831 user_id for item_id 98 is -7.450249681197702
# Prediction for 24831 user_id for item_id 99 is -6.4964710482339445
# Prediction for 24832 user_id for item_id 70 is -7.282487978310181
# Prediction for 24832 user_id for item_id 71 is 1.4106657211937357
# Prediction for 24832 user_id for item_id 72 is -3.1967104523995515
# Prediction for 24832 user_id for item_id 73 is -8.923324416756069
# Prediction for 24832 user_id for item_id 74 is -5.95725505946332
# Prediction for 24832 user_id for item_id 75 is 0.40581295250727095
# Prediction for 24832 user_id for item_id 76 is -4.749289811193446
# Prediction for 24832 user_id for item_id 77 is -2.4499755119601523
# Prediction for 24832 user_id for item_id 78 is -5.2924159935030355
# Prediction for 24832 user_id for item_id 79 is -1.9235298967116183
# Prediction for 24832 user_id for item_id 80 is -0.4282378934253222
# Prediction for 24832 user_id for item_id 81 is -5.359946357893637
# Prediction for 24832 user_id for item_id 82 is 0.35237501433430657
# Prediction for 24832 user_id for item_id 83 is -5.388213577312592
# Prediction for 24832 user_id for item_id 84 is -3.2355782356984206
# Prediction for 24832 user_id for item_id 85 is -7.67922858098809
# Prediction for 24832 user_id for item_id 86 is -1.3137383834011103
# Prediction for 24832 user_id for item_id 87 is -2.008335469522121
# Prediction for 24832 user_id for item_id 88 is 2.357504259858773
# Prediction for 24832 user_id for item_id 89 is -6.11933374241448
# Prediction for 24832 user_id for item_id 90 is -2.4134997172253283
# Prediction for 24832 user_id for item_id 92 is -0.2677903043174516
# Prediction for 24832 user_id for item_id 93 is -6.283544390563882
# Prediction for 24832 user_id for item_id 94 is -4.821291143014717
# Prediction for 24832 user_id for item_id 95 is -3.909302682495483
# Prediction for 24832 user_id for item_id 96 is -3.1200806263833263
# Prediction for 24832 user_id for item_id 97 is -0.7950290768543801
# Prediction for 24832 user_id for item_id 98 is -6.696705719907636
# Prediction for 24832 user_id for item_id 99 is -0.582950651138039
# Prediction for 24833 user_id for item_id 70 is -1.4556974367334377
# Prediction for 24833 user_id for item_id 71 is 4.889871779475321
# Prediction for 24833 user_id for item_id 72 is 2.6645086273746768
# Prediction for 24833 user_id for item_id 73 is -2.563316195421826
# Prediction for 24833 user_id for item_id 74 is -0.053057369157895294
# Prediction for 24833 user_id for item_id 75 is 4.283387546922793
# Prediction for 24833 user_id for item_id 76 is 1.748316665169221
# ...
# Prediction for 24976 user_id for item_id 75 is 6.869655599076823
# Prediction for 24976 user_id for item_id 76 is 5.783829024258653
# Prediction for 24976 user_id for item_id 78 is 5.503038205592536
# Prediction for 24976 user_id for item_id 79 is 7.337830530165313
# Prediction for 24976 user_id for item_id 80 is 6.08500547476014
# Prediction for 24976 user_id for item_id 81 is 4.15399580258152
# Prediction for 24976 user_id for item_id 82 is 7.239633543417178
# Prediction for 24976 user_id for item_id 83 is 4.1519927309765645
# Prediction for 24976 user_id for item_id 84 is 5.649946189528062
# Prediction for 24976 user_id for item_id 85 is 1.4177290844845478
# Prediction for 24976 user_id for item_id 86 is 5.4912340577435685
# Prediction for 24976 user_id for item_id 87 is 4.883280591630891
# Prediction for 24976 user_id for item_id 88 is 7.142901650706725
# Prediction for 24976 user_id for item_id 89 is 3.9012694265602383
# Prediction for 24976 user_id for item_id 90 is 4.6616022268852335
# Prediction for 24976 user_id for item_id 91 is 4.625554647025175
# Prediction for 24976 user_id for item_id 92 is 6.0229859326351995
# Prediction for 24977 user_id for item_id 0 is -0.08528096239647653
# Prediction for 24977 user_id for item_id 1 is 1.279783165836129
# Prediction for 24977 user_id for item_id 2 is -0.380036747143551
# Prediction for 24977 user_id for item_id 3 is -2.7162992030902458
# Prediction for 24977 user_id for item_id 5 is 2.5805476674578927
# Prediction for 24977 user_id for item_id 8 is -4.0842652612007075
# Prediction for 24977 user_id for item_id 9 is -0.14346084784339166
# Prediction for 24977 user_id for item_id 11 is 3.40116593347465
# Prediction for 24977 user_id for item_id 13 is 3.9027086028357716
# Prediction for 24977 user_id for item_id 21 is 1.2301308775514608
# Prediction for 24977 user_id for item_id 22 is -1.585042156779754
# Prediction for 24977 user_id for item_id 23 is -5.125103910743346
# Prediction for 24977 user_id for item_id 24 is 1.14588362792442
# Prediction for 24977 user_id for item_id 25 is 3.7753047394729076
# Prediction for 24977 user_id for item_id 27 is 1.7709794771936769
# Prediction for 24977 user_id for item_id 29 is -2.139930755063065
# Prediction for 24977 user_id for item_id 32 is -3.078301763728369
# Prediction for 24977 user_id for item_id 33 is 2.512875736426228
# Prediction for 24977 user_id for item_id 36 is -4.27123995497719
# Prediction for 24977 user_id for item_id 37 is 0.46953596642259254
# Prediction for 24977 user_id for item_id 38 is 3.070705160073893
# Prediction for 24977 user_id for item_id 39 is 1.7504867525430998
# Prediction for 24977 user_id for item_id 40 is -1.50577346467687
# Prediction for 24977 user_id for item_id 42 is -3.823575530119861
# Prediction for 24977 user_id for item_id 44 is 1.2802475038049888
# Prediction for 24977 user_id for item_id 46 is 2.0189015306870486
# Prediction for 24977 user_id for item_id 50 is 0.20063171527171278
# Prediction for 24977 user_id for item_id 51 is 1.08035929058066
# Prediction for 24977 user_id for item_id 54 is -1.393074498434501
# Prediction for 24977 user_id for item_id 56 is -6.53629585524981
# Prediction for 24977 user_id for item_id 57 is -8.187949439759327
# Prediction for 24977 user_id for item_id 58 is -2.5752095659167162
# Prediction for 24977 user_id for item_id 59 is -3.7267805505641243
# Prediction for 24977 user_id for item_id 62 is -1.1835735413272683
# Prediction for 24977 user_id for item_id 63 is -3.3017738148731848
# Prediction for 24977 user_id for item_id 66 is -3.966079873808875
# Prediction for 24977 user_id for item_id 69 is 0.1273821738835884
# Prediction for 24977 user_id for item_id 71 is 4.768988514167788
# Prediction for 24977 user_id for item_id 72 is 1.898880331020491
# Prediction for 24977 user_id for item_id 74 is -0.9902583419527852
# Prediction for 24977 user_id for item_id 75 is 3.8272464012148415
# Prediction for 24977 user_id for item_id 76 is 0.43473220802101875
# Prediction for 24977 user_id for item_id 77 is 2.3813687058354316
# Prediction for 24977 user_id for item_id 78 is 0.12586577529097506
# Prediction for 24977 user_id for item_id 79 is 2.9095413970154085
# Prediction for 24977 user_id for item_id 80 is 3.292863210619062
# Prediction for 24977 user_id for item_id 81 is -0.48183260166958
# Prediction for 24977 user_id for item_id 83 is -0.47841346346903285
# Prediction for 24977 user_id for item_id 84 is 1.5779492701117102
# Prediction for 24977 user_id for item_id 85 is -3.0735736483059424
# Prediction for 24977 user_id for item_id 86 is 2.3210221553367036
# Prediction for 24977 user_id for item_id 87 is 1.6511916662489226
# Prediction for 24977 user_id for item_id 88 is 4.920227047433079
# Prediction for 24977 user_id for item_id 89 is -1.0260929015259384
# Prediction for 24977 user_id for item_id 90 is 1.2866425602395413
# Prediction for 24977 user_id for item_id 91 is 0.5401968612836738
# Prediction for 24977 user_id for item_id 92 is 3.116597056216382
# Prediction for 24977 user_id for item_id 93 is -1.7707355612988662
# Prediction for 24977 user_id for item_id 94 is -0.728470826026408
# Prediction for 24977 user_id for item_id 95 is 0.2245308315220445
# Prediction for 24977 user_id for item_id 96 is 0.6426557377244172
# Prediction for 24977 user_id for item_id 97 is 2.959740512256101
# Prediction for 24977 user_id for item_id 98 is -1.7813563244832953
# Prediction for 24977 user_id for item_id 99 is 3.418906589998514
# Prediction for 24979 user_id for item_id 70 is 3.4048685697259224
# Prediction for 24979 user_id for item_id 71 is -1.1466617734536357
# Prediction for 24979 user_id for item_id 72 is 1.551674220566784
# Prediction for 24979 user_id for item_id 73 is 5.212384676275754
# Prediction for 24979 user_id for item_id 74 is 3.130168097692729
# Prediction for 24979 user_id for item_id 76 is 1.4847287864817758
# Prediction for 24979 user_id for item_id 77 is 0.45443434557070134
# Prediction for 24979 user_id for item_id 78 is 2.5677611034900667
# Prediction for 24979 user_id for item_id 79 is 1.3662940478947205
# Prediction for 24980 user_id for item_id 0 is -1.1514581419637702
# Prediction for 24980 user_id for item_id 1 is -1.28138347753898
# Prediction for 24980 user_id for item_id 2 is -1.3344709219980357
# Prediction for 24980 user_id for item_id 3 is -1.933657737584533
# Prediction for 24980 user_id for item_id 5 is -0.14984849181852591
# Prediction for 24980 user_id for item_id 8 is -2.3304722069026877
# Prediction for 24980 user_id for item_id 9 is -1.2481751057667851
# Prediction for 24980 user_id for item_id 10 is -0.2750224298537859
# Prediction for 24980 user_id for item_id 11 is -0.37626513797454947
# Prediction for 24980 user_id for item_id 21 is -1.2589399672780142
# Prediction for 24980 user_id for item_id 22 is -1.6208170061348237
# Prediction for 24980 user_id for item_id 23 is -2.5693341319165968
# Prediction for 24980 user_id for item_id 24 is -1.1271594842423152
# Prediction for 24980 user_id for item_id 29 is -1.5705663751045225
# Prediction for 24980 user_id for item_id 32 is -2.127501865903754
# Prediction for 24980 user_id for item_id 33 is -0.5060538268719547
# Prediction for 24980 user_id for item_id 36 is -2.504018729025234
# Prediction for 24980 user_id for item_id 38 is -0.33180222673549586
# Prediction for 24980 user_id for item_id 39 is -0.8234030714354679
# Prediction for 24980 user_id for item_id 42 is -2.0548582503995703
# Prediction for 24980 user_id for item_id 43 is -3.055545921346121
# Prediction for 24980 user_id for item_id 44 is -0.819582398004101
# Prediction for 24980 user_id for item_id 51 is -1.0171703738148905
# Prediction for 24980 user_id for item_id 54 is -1.6005777854548455
# Prediction for 24980 user_id for item_id 56 is -2.9754307480927116
# Prediction for 24980 user_id for item_id 57 is -3.1726133034103574
# Prediction for 24980 user_id for item_id 58 is -1.7999297397984009
# Prediction for 24980 user_id for item_id 59 is -2.277142559806179
# Prediction for 24980 user_id for item_id 62 is -1.296831909209129
# Prediction for 24980 user_id for item_id 63 is -2.1132138328378836
# Prediction for 24980 user_id for item_id 66 is -2.2143324706206164
# Prediction for 24980 user_id for item_id 69 is -0.8602580573701477
# Prediction for 24980 user_id for item_id 70 is -0.8141526280552739
# Prediction for 24980 user_id for item_id 72 is 0.6187045360097938
# Prediction for 24980 user_id for item_id 73 is -1.2369670398249948
# Prediction for 24980 user_id for item_id 74 is -0.26016571408920375
# Prediction for 24980 user_id for item_id 75 is 1.048550597518396
# Prediction for 24980 user_id for item_id 76 is 0.4123455188369716
# Prediction for 24980 user_id for item_id 77 is 0.818860812005595
# Prediction for 24980 user_id for item_id 78 is 0.15421868555503437
# Prediction for 24980 user_id for item_id 79 is 0.7531932572160707
# Prediction for 24980 user_id for item_id 80 is 0.4560521011557933
# Prediction for 24980 user_id for item_id 81 is -0.18875286665388877
# Prediction for 24980 user_id for item_id 82 is 0.9648886103888624
# Prediction for 24980 user_id for item_id 83 is -0.2178266675070672
# Prediction for 24980 user_id for item_id 84 is 0.06992099440614875
# Prediction for 24980 user_id for item_id 85 is -0.9219798201752865
# Prediction for 24980 user_id for item_id 86 is 0.5063754983456114
# Prediction for 24980 user_id for item_id 87 is 0.3303964207698608
# Prediction for 24980 user_id for item_id 88 is 1.4205573958145872
# Prediction for 24980 user_id for item_id 89 is -0.2995727156738999
# Prediction for 24980 user_id for item_id 90 is 0.2935003833772187
# Prediction for 24980 user_id for item_id 91 is 0.1001095002998114
# Prediction for 24980 user_id for item_id 92 is 0.7522219280746493
# Prediction for 24980 user_id for item_id 93 is -0.5595615589616791
# Prediction for 24980 user_id for item_id 94 is -0.37561039182427175
# Prediction for 24980 user_id for item_id 95 is -0.02890174790070064
# Prediction for 24980 user_id for item_id 96 is 0.07074536170840211
# Prediction for 24980 user_id for item_id 97 is 0.21369096186089462
# Prediction for 24980 user_id for item_id 98 is -0.6433939083390555
# Prediction for 24980 user_id for item_id 99 is 0.10649700016812577
# Prediction for 24981 user_id for item_id 0 is -2.3272615944460404
# Prediction for 24981 user_id for item_id 1 is -1.635923249828522
# Prediction for 24981 user_id for item_id 2 is -3.07227364131546
# Prediction for 24981 user_id for item_id 3 is -5.212565611991319
# Prediction for 24981 user_id for item_id 5 is -1.108906513943011
# Prediction for 24981 user_id for item_id 8 is -5.670104452973037
# Prediction for 24981 user_id for item_id 9 is -2.330994359555029
# Prediction for 24981 user_id for item_id 10 is -0.5981736835442031
# Prediction for 24981 user_id for item_id 11 is -0.5622174487118301
# Prediction for 24981 user_id for item_id 13 is -0.2225708533880804
# Prediction for 24981 user_id for item_id 21 is -2.0053788921018483
# Prediction for 24981 user_id for item_id 22 is -3.7795350781202885
# Prediction for 24981 user_id for item_id 23 is -6.386438611249921
# Prediction for 24981 user_id for item_id 24 is -2.158674420419136
# Prediction for 24981 user_id for item_id 29 is -4.858763337108686
# Prediction for 24981 user_id for item_id 32 is -5.270919193744886
# Prediction for 24981 user_id for item_id 33 is -1.1060903748742426
# Prediction for 24981 user_id for item_id 36 is -5.375930009600133
# Prediction for 24981 user_id for item_id 37 is -2.162815366716779
# Prediction for 24981 user_id for item_id 39 is -1.7148750923690554
# Prediction for 24981 user_id for item_id 40 is -4.187453762380075
# Prediction for 24981 user_id for item_id 42 is -5.529438972728305
# Prediction for 24981 user_id for item_id 43 is -6.727305760919017
# Prediction for 24981 user_id for item_id 44 is -1.8875307398477805
# Prediction for 24981 user_id for item_id 46 is -1.2277228066659078
# Prediction for 24981 user_id for item_id 50 is -3.4099587367515234
# Prediction for 24981 user_id for item_id 51 is -2.70100542989304
# Prediction for 24981 user_id for item_id 56 is -6.962398813573413
# Prediction for 24981 user_id for item_id 57 is -8.02307387242676
# Prediction for 24981 user_id for item_id 58 is -4.871144396310621
# Prediction for 24981 user_id for item_id 59 is -4.82083905779178
# Prediction for 24981 user_id for item_id 62 is -3.5809281745823274
# Prediction for 24981 user_id for item_id 63 is -4.982788521388645
# Prediction for 24981 user_id for item_id 66 is -5.5134805001527845
# Prediction for 24981 user_id for item_id 69 is -2.8733115040858226
# Prediction for 24981 user_id for item_id 70 is -4.460590358161495
# Prediction for 24981 user_id for item_id 71 is 0.6574133126097651
# Prediction for 24981 user_id for item_id 72 is -2.0728479505365716
# Prediction for 24981 user_id for item_id 73 is -5.543071285884952
# Prediction for 24981 user_id for item_id 75 is 0.12880113340567861
# Prediction for 24981 user_id for item_id 76 is -2.8867390846532603
# Prediction for 24981 user_id for item_id 77 is -1.5678820141967413
# Prediction for 24981 user_id for item_id 78 is -3.299124207857575
# Prediction for 24981 user_id for item_id 80 is -0.5480182834077659
# Prediction for 24981 user_id for item_id 81 is -3.2894122256075584
# Prediction for 24981 user_id for item_id 82 is -0.011008948419903434
# Prediction for 24981 user_id for item_id 83 is -3.3274600403716352
# Prediction for 24981 user_id for item_id 84 is -2.231717666839036
# Prediction for 24981 user_id for item_id 85 is -4.592263302975825
# Prediction for 24981 user_id for item_id 86 is -0.9150000436992685
# Prediction for 24981 user_id for item_id 87 is -1.2767558057498083
# Prediction for 24981 user_id for item_id 88 is 1.3807497983402564
# Prediction for 24981 user_id for item_id 89 is -3.728139563354607
# Prediction for 24981 user_id for item_id 90 is -1.489165573190676
# Prediction for 24981 user_id for item_id 91 is -2.366567995330337
# Prediction for 24981 user_id for item_id 92 is -0.2593854787838334
# Prediction for 24981 user_id for item_id 93 is -3.7517552568857218
# Prediction for 24981 user_id for item_id 94 is -2.951383148522057
# Prediction for 24981 user_id for item_id 95 is -2.3872713153836793
# Prediction for 24981 user_id for item_id 96 is -1.918585962931321
# Prediction for 24981 user_id for item_id 97 is -0.8679627396085569
# Prediction for 24981 user_id for item_id 98 is -4.117722507248033
# Prediction for 24981 user_id for item_id 99 is -0.8290508106417707
# Prediction for 24982 user_id for item_id 71 is 6.208728480331295
# Prediction for 24982 user_id for item_id 72 is 4.6184197105596105
# Prediction for 24982 user_id for item_id 73 is 1.0784407674417789
# Prediction for 24982 user_id for item_id 74 is 2.60387631386159
# Prediction for 24982 user_id for item_id 75 is 5.951687956853033
# Prediction for 24982 user_id for item_id 76 is 4.551217843751299
# Prediction for 24982 user_id for item_id 77 is 5.596317232768088
# Prediction for 24982 user_id for item_id 78 is 3.733732400803734
# Prediction for 24982 user_id for item_id 79 is 4.716623916966893
# Prediction for 24982 user_id for item_id 80 is 4.7351685159746735
# Prediction for 24982 user_id for item_id 81 is 4.608175814379771
# Prediction for 24982 user_id for item_id 82 is 5.281865221261178
# Prediction for 24982 user_id for item_id 83 is 4.380514063691854
# Prediction for 24982 user_id for item_id 84 is 3.85420686116835
# Prediction for 24982 user_id for item_id 85 is 3.632949328841524
# Prediction for 24982 user_id for item_id 87 is 5.697617922912399
# Prediction for 24982 user_id for item_id 88 is 7.289474211492241
# Prediction for 24982 user_id for item_id 89 is 4.44841136584248
# Prediction for 24982 user_id for item_id 90 is 5.644266812546998
# Prediction for 24982 user_id for item_id 91 is 4.950767148172544
# Prediction for 24982 user_id for item_id 92 is 6.151845699917117
# Prediction for 24982 user_id for item_id 93 is 4.907272387993733
# Prediction for 24982 user_id for item_id 94 is 4.403954226007568
# Prediction for 24982 user_id for item_id 95 is 5.284109385592708
# Prediction for 24982 user_id for item_id 96 is 5.225106401057937
# Prediction for 24982 user_id for item_id 97 is 3.196520495135123
# Prediction for 24982 user_id for item_id 98 is 3.345280980818478
# Prediction for 24982 user_id for item_id 99 is 3.534231400438779

# %%
test_idx
# Out:
# (array([    0,     0,     0, ..., 24982, 24982, 24982]),
#  array([70, 71, 72, ..., 97, 98, 99]))

# %%
num_iter = 100
hist = sgd(num_iter)  # Note how the MSE decreases with the number of iterations
plt.figure()
plt.plot(np.arange(0, num_iter, 5), hist)
plt.xlabel("Iterations")
plt.ylabel("MSE")
plt.show()
# Out:
# Iteration 0/100:	MSE=25.652842
# Iteration 5/100:	MSE=24.486616
# Iteration 10/100:	MSE=23.813462
# Iteration 15/100:	MSE=22.945091
# Iteration 20/100:	MSE=21.167428
# Iteration 25/100:	MSE=18.722917
# Iteration 30/100:	MSE=17.763463
# Iteration 35/100:	MSE=17.474668
# Iteration 40/100:	MSE=17.333030
# Iteration 45/100:	MSE=17.231617
# Iteration 50/100:	MSE=17.137678
# Iteration 55/100:	MSE=17.033929
# Iteration 60/100:	MSE=16.909005
# Iteration 65/100:	MSE=16.757455
# Iteration 70/100:	MSE=16.581676
# Iteration 75/100:	MSE=16.393011
# Iteration 80/100:	MSE=16.209252
# Iteration 85/100:	MSE=16.046533
# Iteration 90/100:	MSE=15.911904
# Iteration 95/100:	MSE=15.803768

# %%
jester_nan.iloc[55,13]
# Out:
# 6.07

# %%
df_items = pd.read_excel('https://github.com/albanda/CE888/blob/master/lab4-recommender/movies_latent_factors.xlsx?raw=true')
df_users = pd.read_excel('https://github.com/albanda/CE888/blob/master/lab4-recommender/movies_latent_factors.xlsx?raw=true', sheet_name=1)

# %%
df_users.set_index('User', inplace=True)

# %%
df_items.set_index('Movie ID', inplace=True)

# %%
df_items[df_items['Factor15'] == df_items['Factor15'].min()]
# Out:
#                                                       Title  ...  Factor15
# Movie ID                                                     ...
# 22        Pirates of the Caribbean: The Curse of the Bla...  ... -2.292566
#
# [1 rows x 16 columns]

# %%
items_latent = df_items.drop('Title', axis=1).values

# %%
user_latent = df_users.values

# %%
user_latent.shape
# Out:
# (25, 15)

# %%
items_latent.shape
# Out:
# (100, 15)

# %%
def predict_movie_rating(user, movie):
  user_arr = df_users.loc[user].values
  movie_arr = df_items.loc[movie].drop('Title').values
  return user_arr.dot(movie_arr)

# %%
def top_n_recommendation(user, n):
  pred = {}
  for movie in df_items.index:
    pred[movie] = predict_movie_rating(user, movie)
  pred = dict(sorted(pred.items(), key=lambda kv: kv[1], reverse=True))
  movies = list(pred.keys())
  return movies[:n]

# %%
predict_movie_rating(783, 807)
# Out:
# -0.08373521823436945

# %%
predict_movie_rating(156, 9331)
# Out:
# -0.041432658849076896

# %%
top_n_recommendation(4940, 3)
# Out:
# [13, 278, 603]

# %%
df_items.loc[top_n_recommendation(1882, 2)]['Title']
# Out:
# Movie ID
# 604    The Matrix Reloaded (2003)
# 603             The Matrix (1999)
# Name: Title, dtype: object
